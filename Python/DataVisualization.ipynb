# %%
import numpy as np
import matplotlib.pyplot as plt
x_axis = ["1","2","3","4","9","11"]
y_axis = ["1","2","7","5","2","3"]
plt.scatter(x_axis, y_axis)
plt.title("hello scatter")
plt.xlabel("Total_bill")
plt.ylabel("Tip")
plt.show()

# %%
import matplotlib.pyplot as plt
x_axis = ["1","2","3","4","9","11"]
y_axis = ["1","2","7","5","2","3"]
plt.plot(x_axis, y_axis)
plt.title("hello scatter")
plt.xlabel("Total_bill")
plt.ylabel("Tip")
plt.show()

# %%
import matplotlib.pyplot as plt
x_axis = ["1","2","3","4","9","11"]
y_axis = ["1","2","7","5","2","3"]
plt.bar(x_axis, y_axis)
plt.title("bar plot")
plt.xlabel("Total_bill")
plt.ylabel("Tip")
plt.show()

# %%
import matplotlib.pyplot as plt
data = ["1","1","2","3","3","4","5","6","6","7","8"]
#y_axis = ["1","2","7","5","2","3"]
plt.hist(data,bins=10)
plt.title("hello histogram")
plt.show()
